# %%
#import the key libraries
from bs4 import BeautifulSoup
from datetime import datetime

import requests
import csv
import re
import time
import datetime

#need to store the data in a dataframe
import pandas as pd

# %%
#initialize the variables
debugFlag = 0
uniqueid = 0

gowers_article_list = []
tao_article_list = []

# %%
#create the empty dataframe for initial posts and comments
polymath_BERT = pd.DataFrame(columns = ['post_source','post_url','post_timestamp', 'comment_timestamp','post_title','counter', 'post_author', 'post_word_count','post_text'])
print(polymath_BERT)
# Out:
# Empty DataFrame
# Columns: [post_source, post_url, post_timestamp, comment_timestamp, post_title, counter, post_author, post_word_count, post_text]
# Index: []

# %%
### Reads from csv source and appends to article link list
#changes from source code:
# switched to 'r' so it wasn't a binary file; 
# added encoding - the utf-8-sig removes the '\ufeff' that was showing up at the beginning of the first row
with open('/Users/jennaolsen/Desktop/mothership-gowers-articles-list.csv', 'r', encoding="utf-8-sig") as f:
	reader = csv.reader(f)
	for row in reader:
		gowers_article_list.append(row)

# %%
### Reads from csv source and appends to article link list
#changes from source code:
# switched to 'r' so it wasn't a binary file; 
# added encoding - the utf-8-sig removes the '\ufeff' that was showing up at the beginning of the first row
with open('/Users/jennaolsen/Desktop/mothership-tao-articles-list.csv', 'r', encoding="utf-8-sig") as f:
	reader = csv.reader(f)
	for row in reader:
		tao_article_list.append(row)

# %%
# ###  Checks the content of the article_link_list
# for row in gowers_article_list:
# 	print((row))
print(len(tao_article_list))
# Out:
# 26

# %%
# pulling data from the gowers primary posts
for article_link in gowers_article_list:

	# Masking nature of the bot
	if int(datetime.datetime.now().second) % 3 == 0:
		user_agent = 'Mozilla/5 (Solaris 10) Gecko'
	elif int(datetime.datetime.now().second) % 5 == 0:
		user_agent = 'Mozilla/4.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/5.0)'
	else:
		user_agent = 'Mozilla/5.0 (compatible; MSIE 5.5; Windows NT)'

	headers = {'User-Agent': user_agent}

	time.sleep(1.4)

# 	print "\n\n=====Task ID: " + str(uniqueid) + "=====\n"

	article_link = ''.join(article_link)
	print ("Now scraping: " + article_link + "...")
	r = requests.get(article_link)
	soupData = BeautifulSoup(r.text)

	### Scraping the title - had to remove the encoding because it killed concate operation in the next line
	title = soupData.find('h2').text
# 	title = title.encode('utf-8-sig').strip()
# 	print ("Title: " + title)

# <meta property="article:published_time" content="2009-02-01T12:43:20+00:00" />

	### Scraping the timestamp
	timestamp = soupData.find("meta", property="article:published_time")
	ts = timestamp["content"]
	print ("Published Time: " + ts.replace('T',' ').replace('+00:00',''))

	### Scraping the entry
	entry = soupData.find_all("div", {"class": "entry"})
	post_content = str(entry)
	### Parsing the text into a beautfulsoup item
	parsed_post_content = BeautifulSoup(post_content)
	### Find all paragraphs/blog content
	content_tokens = parsed_post_content.findAll('p')
	### The last 2 paragraphs are unwanted
# 	advert_text = content_tokens[len(content_tokens)-1]
	### parse to string form
	advert_text = str(content_tokens)
	### parse to string form as well
# 	post_content = parsed_post_content.text
	post_content = post_content.replace(advert_text, "")
	### To remove all newlines
	post_content = post_content.replace("\n", "").replace("\r", "").strip()
	### To remove all tags
	post_content = BeautifulSoup(post_content, "lxml").text
    ### To remove the garbage left at the end of the text
	post_content = post_content.replace("Share this:TwitterFacebookLike this:Like Loading...Related", "").strip()#.encode('utf-8')
    
    ###word count for the post 
	word_count = len(post_content.split())
    
    ###Add the new row to the dataframe 
	new_row = {'post_source':'Gowers','post_url':article_link,'post_timestamp':ts,'post_title':title,'counter':'0', 'post_author':'gowers', 'post_word_count':word_count, 'post_text':post_content}
	polymath_BERT = polymath_BERT.append(new_row, ignore_index=True)
# Out:
# Now scraping: https://gowers.wordpress.com/2009/01/27/is-massively-collaborative-mathematics-possible/...
# Published Time: 2009-01-27 15:47:52
# Now scraping: https://gowers.wordpress.com/2009/01/30/background-to-a-polymath-project/...
# Published Time: 2009-01-30 10:51:09
# Now scraping: https://gowers.wordpress.com/2009/02/01/questions-of-procedure/...
# Published Time: 2009-02-01 12:41:44
# Now scraping: https://gowers.wordpress.com/2009/02/01/a-combinatorial-approach-to-density-hales-jewett/...
# Published Time: 2009-02-01 12:43:20
# Now scraping: https://gowers.wordpress.com/2009/02/01/why-this-particular-problem/...
# Published Time: 2009-02-01 12:44:03
# Now scraping: https://gowers.wordpress.com/2009/02/04/quick-question/...
# Published Time: 2009-02-04 12:07:03
# Now scraping: https://gowers.wordpress.com/2009/02/06/dhj-the-triangle-removal-approach/...
# Published Time: 2009-02-06 09:03:36
# Now scraping: https://gowers.wordpress.com/2009/02/08/dhj-quasirandomness-and-obstructions-to-uniformity/...
# Published Time: 2009-02-08 15:53:27
# Now scraping: https://gowers.wordpress.com/2009/02/13/dhj-possible-proof-strategies/...
# Published Time: 2009-02-13 07:27:07
# Now scraping: https://gowers.wordpress.com/2009/02/21/to-thread-or-not-to-thread/...
# Published Time: 2009-02-21 19:04:49
# Now scraping: https://gowers.wordpress.com/2009/02/23/brief-review-of-polymath1/...
# Published Time: 2009-02-23 09:57:22
# Now scraping: https://gowers.wordpress.com/2009/03/02/dhj3-851-899/...
# Published Time: 2009-03-01 23:37:59
# Now scraping: https://gowers.wordpress.com/2009/03/10/problem-solved-probably/...
# Published Time: 2009-03-09 23:21:18
# Now scraping: https://gowers.wordpress.com/2009/03/10/polymath1-and-open-collaborative-mathematics/...
# Published Time: 2009-03-10 21:42:03
# Now scraping: https://gowers.wordpress.com/2009/03/16/dhj3-and-related-results-1050-1099/...
# Published Time: 2009-03-16 12:16:32
# Now scraping: https://gowers.wordpress.com/2009/03/24/can-polymath-be-scaled-up/...
# Published Time: 2009-03-24 08:57:10
# Now scraping: https://gowers.wordpress.com/2009/06/25/dhj-write-up-and-other-matters/...
# Published Time: 2009-06-25 09:55:44
# Now scraping: https://gowers.wordpress.com/2009/10/20/miscellaneous-matters/...
# Published Time: 2009-10-20 13:40:33
# Now scraping: https://gowers.wordpress.com/2010/02/17/dhj-latest/...
# Published Time: 2010-02-17 00:14:17
# Now scraping: https://gowers.wordpress.com/2012/04/23/polymath-paper-published/...
# Published Time: 2012-04-23 20:05:09

# %%
# pulling comments from the various articles
# move into main section once it is working
for article_link in gowers_article_list:

	# Masking nature of the bot
	if int(datetime.datetime.now().second) % 3 == 0:
		user_agent = 'Mozilla/5 (Solaris 10) Gecko'
	elif int(datetime.datetime.now().second) % 5 == 0:
		user_agent = 'Mozilla/4.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/5.0)'
	else:
		user_agent = 'Mozilla/5.0 (compatible; MSIE 5.5; Windows NT)'

	headers = {'User-Agent': user_agent}

	time.sleep(1.4)

	article_link = ''.join(article_link)
	print ("Now scraping: " + article_link + "...") # the "post_url" field
	r = requests.get(article_link)
	soupData = BeautifulSoup(r.text)
    
### Scraping for comments
	comments_count = soupData.find_all("li", attrs={"id" : True})
	for cc in comments_count:
		ident = cc["id"].replace("comment-","C").strip()
# 		print(ident) #this will be the "counter" field
        
		time_string = cc.find("small").text.replace(" | Reply ","").strip()
# 		print(time_string) # the "post_timestamp" field
        
		the_comment = str(cc.findAll("p"))
		the_comment = BeautifulSoup(the_comment, "lxml").text
# 		print(the_comment) # the "post_text" field

		author = cc.find("cite").string
# 		print(author) # the "post_text" field

		word_count = len(str(the_comment).split())

        ###insert the rw into the dataframe
		new_row = {'post_source':'Gowers','post_url':article_link,'comment_timestamp':time_string,'post_title':'','counter':ident, 'post_author':author, 'post_word_count':word_count, 'post_text':the_comment}
		polymath_BERT = polymath_BERT.append(new_row, ignore_index=True)
# Out:
# Now scraping: https://gowers.wordpress.com/2009/01/27/is-massively-collaborative-mathematics-possible/...
# Now scraping: https://gowers.wordpress.com/2009/01/30/background-to-a-polymath-project/...
# Now scraping: https://gowers.wordpress.com/2009/02/01/questions-of-procedure/...
# Now scraping: https://gowers.wordpress.com/2009/02/01/a-combinatorial-approach-to-density-hales-jewett/...
# Now scraping: https://gowers.wordpress.com/2009/02/01/why-this-particular-problem/...
# Now scraping: https://gowers.wordpress.com/2009/02/04/quick-question/...
# Now scraping: https://gowers.wordpress.com/2009/02/06/dhj-the-triangle-removal-approach/...
# Now scraping: https://gowers.wordpress.com/2009/02/08/dhj-quasirandomness-and-obstructions-to-uniformity/...
# Now scraping: https://gowers.wordpress.com/2009/02/13/dhj-possible-proof-strategies/...
# Now scraping: https://gowers.wordpress.com/2009/02/21/to-thread-or-not-to-thread/...
# Now scraping: https://gowers.wordpress.com/2009/02/23/brief-review-of-polymath1/...
# Now scraping: https://gowers.wordpress.com/2009/03/02/dhj3-851-899/...
# Now scraping: https://gowers.wordpress.com/2009/03/10/problem-solved-probably/...
# Now scraping: https://gowers.wordpress.com/2009/03/10/polymath1-and-open-collaborative-mathematics/...
# Now scraping: https://gowers.wordpress.com/2009/03/16/dhj3-and-related-results-1050-1099/...
# Now scraping: https://gowers.wordpress.com/2009/03/24/can-polymath-be-scaled-up/...
# Now scraping: https://gowers.wordpress.com/2009/06/25/dhj-write-up-and-other-matters/...
# Now scraping: https://gowers.wordpress.com/2009/10/20/miscellaneous-matters/...
# Now scraping: https://gowers.wordpress.com/2010/02/17/dhj-latest/...
# Now scraping: https://gowers.wordpress.com/2012/04/23/polymath-paper-published/...

# %%
###  Checks the content of the article_link_list
for row in tao_article_list:
	print((row))
print(len(tao_article_list))
# Out:
# ['https://terrytao.wordpress.com/2009/02/01/a-massively-collaborative-mathematical-project/']
# ['https://terrytao.wordpress.com/2009/02/05/upper-and-lower-bounds-for-the-density-hales-jewett-problem/']
# ['https://terrytao.wordpress.com/2009/02/05/upper-and-lower-bounds-for-the-density-hales-jewett-problem/comment-page-1/#comments']
# ['https://terrytao.wordpress.com/2009/02/11/a-reading-seminar-on-density-hales-jewett/']
# ['https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/']
# ['https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/comment-page-2/#comments']
# ['https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/comment-page-1/#comments']
# ['https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/']
# ['https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/comment-page-2/#comments']
# ['https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/comment-page-1/#comments']
# ['https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/']
# ['https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/comment-page-2/#comments']
# ['https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/comment-page-1/#comments']
# ['https://terrytao.wordpress.com/2009/03/30/dhjk-1200-1299-density-hales-jewett-type-numbers/']
# ['https://terrytao.wordpress.com/2009/03/30/dhjk-1200-1299-density-hales-jewett-type-numbers/comment-page-1/#comments']
# ['https://terrytao.wordpress.com/2009/04/02/polymath1-and-three-new-proofs-of-the-density-hales-jewett-theorem/']
# ['https://terrytao.wordpress.com/2009/05/22/dhj-writing-the-second-paper/']
# ['https://terrytao.wordpress.com/2009/05/22/dhj-writing-the-second-paper/comment-page-2/#comments']
# ['https://terrytao.wordpress.com/2009/05/22/dhj-writing-the-second-paper/comment-page-1/#comments']
# ['https://terrytao.wordpress.com/2009/06/14/dhj-still-writing-the-second-paper/']
# ['https://terrytao.wordpress.com/2009/06/14/dhj-still-writing-the-second-paper/comment-page-2/#comments']
# ['https://terrytao.wordpress.com/2009/06/14/dhj-still-writing-the-second-paper/comment-page-1/#comments']
# ['https://terrytao.wordpress.com/2009/07/09/dhj-writing-the-second-paper-iii/']
# ['https://terrytao.wordpress.com/2009/10/22/a-new-proof-of-the-density-hales-jewett-theorem/']
# ['https://terrytao.wordpress.com/2010/01/15/density-hales-jewett-and-moser-numbers-nearing-the-final-draft/']
# ['https://terrytao.wordpress.com/2010/04/22/dhj-polymath-paper-accepted/']
# 26

# %%
# pulling data from the various articles
for article_link in tao_article_list:

	# Masking nature of the bot
	if int(datetime.datetime.now().second) % 3 == 0:
		user_agent = 'Mozilla/5 (Solaris 10) Gecko'
	elif int(datetime.datetime.now().second) % 5 == 0:
		user_agent = 'Mozilla/4.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/5.0)'
	else:
		user_agent = 'Mozilla/5.0 (compatible; MSIE 5.5; Windows NT)'

	headers = {'User-Agent': user_agent}

	time.sleep(1.4)

	article_link = ''.join(article_link)
	print ("Now scraping: " + article_link + "...")
	r = requests.get(article_link)
	soupData = BeautifulSoup(r.text)

	### Scraping the title - had to remove the encoding because it killed concate operation in the next line
	title = soupData.find('title').text.replace(" | What's new","")
# 	print ("Title: " + title)

	### Scraping the timestamp
	timestamp = soupData.find("meta", property="article:published_time")
# 	print ("Published Time: " + timestamp["content"])
	ts = timestamp["content"]

	### Scraping the entry
	entry = soupData.find_all("div", {"class": "post-content"})
	post_content = str(entry)
	### Parsing the text into a beautfulsoup item
	parsed_post_content = BeautifulSoup(post_content)
	### parse to string form
	advert_text = parsed_post_content.text
	## parse to string form as well
	post_content = advert_text
    ### To remove the garbage left at the end of the text
	post_content = post_content.replace("Further articles on this project are collected at this page.", "").replace("<\b>", "")
	post_content = post_content.replace("\n\nShare this:PrintEmailMoreTwitterFacebookRedditPinterestLike this:Like Loading... ", "").strip().encode('utf-8')
# 	print (post_content)
   
	## parse to string form as well
	post_content = BeautifulSoup(post_content, "lxml").text
   
	##word count of post
	word_count = len(post_content.split())
    
#     ###Add the new row to the dataframe 
	new_row = {'post_source':'Tao','post_url':article_link,'post_timestamp':ts,'post_title':title,'counter':'0', 'post_author':'Tao', 'post_word_count':word_count, 'post_text':post_content}
	polymath_BERT = polymath_BERT.append(new_row, ignore_index=True)
# Out:
# Now scraping: https://terrytao.wordpress.com/2009/02/01/a-massively-collaborative-mathematical-project/...
# Now scraping: https://terrytao.wordpress.com/2009/02/05/upper-and-lower-bounds-for-the-density-hales-jewett-problem/...
# Now scraping: https://terrytao.wordpress.com/2009/02/05/upper-and-lower-bounds-for-the-density-hales-jewett-problem/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/02/11/a-reading-seminar-on-density-hales-jewett/...
# Now scraping: https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/...
# Now scraping: https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/...
# Now scraping: https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/...
# Now scraping: https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/30/dhjk-1200-1299-density-hales-jewett-type-numbers/...
# Now scraping: https://terrytao.wordpress.com/2009/03/30/dhjk-1200-1299-density-hales-jewett-type-numbers/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/04/02/polymath1-and-three-new-proofs-of-the-density-hales-jewett-theorem/...
# Now scraping: https://terrytao.wordpress.com/2009/05/22/dhj-writing-the-second-paper/...
# Now scraping: https://terrytao.wordpress.com/2009/05/22/dhj-writing-the-second-paper/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/05/22/dhj-writing-the-second-paper/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/06/14/dhj-still-writing-the-second-paper/...
# Now scraping: https://terrytao.wordpress.com/2009/06/14/dhj-still-writing-the-second-paper/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/06/14/dhj-still-writing-the-second-paper/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/07/09/dhj-writing-the-second-paper-iii/...
# Now scraping: https://terrytao.wordpress.com/2009/10/22/a-new-proof-of-the-density-hales-jewett-theorem/...
# Now scraping: https://terrytao.wordpress.com/2010/01/15/density-hales-jewett-and-moser-numbers-nearing-the-final-draft/...
# Now scraping: https://terrytao.wordpress.com/2010/04/22/dhj-polymath-paper-accepted/...

# %%
for article_link in tao_article_list:

	# Masking nature of the bot
	if int(datetime.datetime.now().second) % 3 == 0:
		user_agent = 'Mozilla/5 (Solaris 10) Gecko'
	elif int(datetime.datetime.now().second) % 5 == 0:
		user_agent = 'Mozilla/4.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/5.0)'
	else:
		user_agent = 'Mozilla/5.0 (compatible; MSIE 5.5; Windows NT)'

	headers = {'User-Agent': user_agent}

	time.sleep(1.4)

	comment_count = 0
    
	article_link = ''.join(article_link)
	print ("Now scraping: " + article_link + "...") # the "post_url" field
	r = requests.get(article_link)
	soupData = BeautifulSoup(r.text)
    
### Scraping for comments
### Comments for Tao show up with two different tags (so far) - this structure allows find_all to find both of them  'div[class*="listing-col-"]'
	comments_count = soupData.select('div[class*="-comment"]')
	for cc in comments_count:
        #Adding the CTao in front of the number to avoid duplication with Gowers blog posts
		ident = cc["id"].replace("comment-","CTao_").strip()
# 		print(ident) #this will be the "counter" field


        #Temporary to identify the posts where I am missing some comments
		comment_count+=1
# 		print(ident) #this will be the "counter" field

        
		time_string = cc.find("p", attrs={"class":"comment-permalink"}).text.strip()
# 		print(time_string) # the "post_timestamp" field
        
		the_comment = str(cc.find("div", attrs={"class":"comment-content"}).findAll("p"))
		the_comment = BeautifulSoup(the_comment, "lxml").text
# 		print(the_comment) # the "post_text" field
        
		the_author = cc.find("p", attrs={"class":"comment-author"}).find("strong").string
# 		print(the_author) # the "post_text" field
        
		word_count = len(str(the_comment).split())

        ###insert the rw into the dataframe
		new_row = {'post_source':'Tao','post_url':article_link,'comment_timestamp':time_string,'post_title':'','counter':ident, 'post_author':the_author, 'post_word_count':word_count, 'post_text':the_comment}
		polymath_BERT = polymath_BERT.append(new_row, ignore_index=True)
# Out:
# Now scraping: https://terrytao.wordpress.com/2009/02/01/a-massively-collaborative-mathematical-project/...
# Now scraping: https://terrytao.wordpress.com/2009/02/05/upper-and-lower-bounds-for-the-density-hales-jewett-problem/...
# Now scraping: https://terrytao.wordpress.com/2009/02/05/upper-and-lower-bounds-for-the-density-hales-jewett-problem/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/02/11/a-reading-seminar-on-density-hales-jewett/...
# Now scraping: https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/...
# Now scraping: https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/...
# Now scraping: https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/...
# Now scraping: https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/03/30/dhjk-1200-1299-density-hales-jewett-type-numbers/...
# Now scraping: https://terrytao.wordpress.com/2009/03/30/dhjk-1200-1299-density-hales-jewett-type-numbers/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/04/02/polymath1-and-three-new-proofs-of-the-density-hales-jewett-theorem/...
# Now scraping: https://terrytao.wordpress.com/2009/05/22/dhj-writing-the-second-paper/...
# Now scraping: https://terrytao.wordpress.com/2009/05/22/dhj-writing-the-second-paper/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/05/22/dhj-writing-the-second-paper/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/06/14/dhj-still-writing-the-second-paper/...
# Now scraping: https://terrytao.wordpress.com/2009/06/14/dhj-still-writing-the-second-paper/comment-page-2/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/06/14/dhj-still-writing-the-second-paper/comment-page-1/#comments...
# Now scraping: https://terrytao.wordpress.com/2009/07/09/dhj-writing-the-second-paper-iii/...
# Now scraping: https://terrytao.wordpress.com/2009/10/22/a-new-proof-of-the-density-hales-jewett-theorem/...
# Now scraping: https://terrytao.wordpress.com/2010/01/15/density-hales-jewett-and-moser-numbers-nearing-the-final-draft/...
# Now scraping: https://terrytao.wordpress.com/2010/04/22/dhj-polymath-paper-accepted/...

# %%
#ready to set up for the BERT analysis now :)

# %%
### checking for the full count
### 1543 comments and 20 posts from Gowers
### 888 comments and 14 posts from Tao (26???)
print(polymath_BERT)
# Out:
#      post_source                                           post_url  \
# 0         Gowers  https://gowers.wordpress.com/2009/01/27/is-mas...
# 1         Gowers  https://gowers.wordpress.com/2009/01/30/backgr...
# 2         Gowers  https://gowers.wordpress.com/2009/02/01/questi...
# 3         Gowers  https://gowers.wordpress.com/2009/02/01/a-comb...
# 4         Gowers  https://gowers.wordpress.com/2009/02/01/why-th...
# ...          ...                                                ...
# 1588         Tao  https://terrytao.wordpress.com/2009/06/14/dhj-...
# 1589         Tao  https://terrytao.wordpress.com/2009/07/09/dhj-...
# 1590         Tao  https://terrytao.wordpress.com/2009/10/22/a-ne...
# 1591         Tao  https://terrytao.wordpress.com/2010/01/15/dens...
# 1592         Tao  https://terrytao.wordpress.com/2010/04/22/dhj-...
#
#                  post_timestamp comment_timestamp  \
# 0     2009-01-27T15:47:52+00:00               NaN
# 1     2009-01-30T10:51:09+00:00               NaN
# 2     2009-02-01T12:41:44+00:00               NaN
# 3     2009-02-01T12:43:20+00:00               NaN
# 4     2009-02-01T12:44:03+00:00               NaN
# ...                         ...               ...
# 1588  2009-06-14T09:22:32+00:00               NaN
# 1589  2009-07-09T16:28:16+00:00               NaN
# 1590  2009-10-22T22:28:05+00:00               NaN
# 1591  2010-01-16T07:22:44+00:00               NaN
# 1592  2010-04-22T17:26:39+00:00               NaN
#
#                                              post_title counter post_author  \
# 0      Is massively collaborative mathematics possible?       0      gowers
# 1                      Background to a Polymath project       0      gowers
# 2                                Questions of procedure       0      gowers
# 3      A combinatorial approach to density Hales-Jewett       0      gowers
# 4                          Why this particular problem?       0      gowers
# ...                                                 ...     ...         ...
# 1588                DHJ: Still writing the second paper       0         Tao
# 1589                 DHJ: Writing the second paper III.       0         Tao
# 1590    A new proof of the density Hales-Jewett theorem       0         Tao
# 1591  “Density Hales-Jewett and Moser numbers” – nea...       0         Tao
# 1592                        DHJ Polymath paper accepted       0         Tao
#
#      post_word_count                                          post_text
# 0               2582  [Of course, one might say, there are certain k...
# 1               2021  [This post contains brief descriptions of some...
# 2               1883  [As a result of comments on my post Is Massive...
# 3               3271  [Here then is the project that I hope it might...
# 4                615  [Let me briefly try to defend my choice of pro...
# ...              ...                                                ...
# 1588             162  [\nThis is a continuation of the previous thre...
# 1589             130  [\nThis is a continuation of the preceding two...
# 1590             400  [\nThe polymath1 project has just uploaded to ...
# 1591             339  [\nAfter a hiatus of several months, I’ve made...
# 1592             605  [\nOrdinarily, I only mention my research pape...
#
# [1593 rows x 9 columns]

# %%
# polymath_BERT.to_excel('polymath_BERT_wordCounts.xlsx')
